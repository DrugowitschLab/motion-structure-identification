# %%
from analysis.data_analysis import fit_model_to_exp1, plot_exp2_prediction
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams.update({'font.size': 12})
names = [
    'johannes_0805',
    'sichao_0806',
    'pilot1_0806',
    'pilot2_0808',
]
σs = [1.7, 0.5, 2.1, 0.6]
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 9), dpi=160)
for name, σ_R, ax in zip(names, σs, [axes[0, 0], axes[0, 1], axes[1, 0], axes[1, 1]]):
    plt.sca(ax)
    ax.set_title(name.split('_')[0])
    𝜃 = fit_model_to_exp1(f'../data/exp1/{name}/{name}.dat', np.array([[0.1, 0.1, 0, 0, 0]]), σ_R=σ_R).x
    print(𝜃)
    print(plot_exp2_prediction(f'../data/exp2/{name}/{name}.dat', np.array([𝜃[0], 𝜃[1], 𝜃[-1] - 𝜃[-2]]), σ_R=σ_R, ax=ax))
plt.tight_layout()
plt.show()
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 94.56058670957853
#             Iterations: 18
#             Function evaluations: 144
#             Gradient evaluations: 18
#      fun: 94.56058670957853
#      jac: array([ 1.81198120e-05, -9.01222229e-03, -2.74658203e-04, -3.40270996e-03,
#         2.85053253e-03])
#  message: 'Optimization terminated successfully.'
#     nfev: 144
#      nit: 18
#     njev: 18
#   status: 0
#  success: True
#        x: array([ 0.001     ,  0.79461345, -0.20562556,  0.7642479 ,  0.41604257])
# [ 0.001       0.79461345 -0.20562556  0.7642479   0.41604257]
# [0.8, 0.65, 0.65, 0.55, 0.35]
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 123.27435902554146
#             Iterations: 19
#             Function evaluations: 150
#             Gradient evaluations: 19
#      fun: 123.27435902554146
# ...
