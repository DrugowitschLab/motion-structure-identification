# %%
from analysis.confusion_matrix import plot_cm
from analysis.model import plot_prediction

# %%
plot_cm('sichao/pilot_sichao.dat')
# Out:
# [[42  1  6  3]
#  [ 0 33  1  0]
#  [ 3  0 38 11]
#  [ 5  8 26 23]]
# accuracy=0.6800; misclass=0.3200

# %%
plot_prediction('pilot_0.csv', 'Sichao_choice', lapse=False)
# Out:
# /home/sichao/Documents/Motion/code/sichao/analysis/model.py:38: RuntimeWarning: divide by zero encountered in log
#   loss = -np.log(loss).sum()
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 166.9173428048616
#             Iterations: 55
#             Function evaluations: 341
#             Gradient evaluations: 55
# [1.46082787e-03 2.70460290e+03 1.38674832e+03 9.25894603e+02]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.875283  0.000900  0.082802  0.041015
# GLO           0.004686  0.710724  0.178158  0.106432
# CLU           0.050390  0.003236  0.640378  0.305996
# SDH           0.027482  0.284230  0.440935  0.247353

# %%
plot_prediction('pilot_0.04309087(sichao).csv', 'Sichao_choice', lapse=False)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 157.10345054831893
#             Iterations: 28
#             Function evaluations: 176
#             Gradient evaluations: 28
# [2.71934485e-02 1.23112799e+02 5.75901607e+01 3.22942612e+01]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.864981  0.002996  0.091405  0.040618
# GLO           0.003877  0.757046  0.135237  0.103840
# CLU           0.055277  0.012336  0.664661  0.267727
# SDH           0.032464  0.249432  0.436879  0.281225

# %%
plot_prediction('pilot_1.csv', 'Sichao_choice', lapse=False)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 159.7365024068278
#             Iterations: 13
#             Function evaluations: 87
#             Gradient evaluations: 13
# [ 0.22174303  5.66621351  0.42257394 -3.31581131]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.762748  0.008062  0.169893  0.059297
# GLO           0.007115  0.784495  0.107303  0.101086
# CLU           0.107892  0.041750  0.643097  0.207261
# SDH           0.072333  0.205429  0.404467  0.317771

# %%
plot_cm('johannes/pilot_johannes.dat')
# Out:
# [[36  1  9  6]
#  [ 1 32  0  1]
#  [ 3  0 37 12]
#  [ 5  8 25 24]]
# accuracy=0.6450; misclass=0.3550

# %%
plot_prediction('pilot_0.csv', 'Johannes_choice', lapse=False)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 190.0752509726836
#             Iterations: 53
#             Function evaluations: 329
#             Gradient evaluations: 53
# [1.20660457e-03 2.98781937e+03 1.52149221e+03 1.09032275e+03]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.762585  0.003251  0.148228  0.085937
# GLO           0.007230  0.644081  0.207891  0.140799
# CLU           0.061282  0.008450  0.594884  0.335384
# SDH           0.030903  0.298242  0.407901  0.262954

# %%
plot_prediction('pilot_0.08447111(johannes).csv', 'Johannes_choice', lapse=False)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 178.27707236919287
#             Iterations: 28
#             Function evaluations: 177
#             Gradient evaluations: 28
# [3.22835045e-02 9.69943119e+01 4.72776498e+01 3.07851357e+01]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.761491  0.005891  0.153180  0.079438
# GLO           0.005653  0.684703  0.167527  0.142117
# CLU           0.059772  0.026586  0.615786  0.297856
# SDH           0.033903  0.258569  0.408352  0.299176

# %%
plot_prediction('pilot_1.csv', 'Johannes_choice', lapse=False)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 162.92131562029948
#             Iterations: 15
#             Function evaluations: 99
#             Gradient evaluations: 15
# [ 0.22290582  7.03122996  1.8642174  -1.10860789]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.724275  0.008379  0.189734  0.077612
# GLO           0.005037  0.771421  0.105600  0.117942
# CLU           0.077459  0.040503  0.640459  0.241579
# SDH           0.050626  0.197248  0.390963  0.361163

# %%
plot_prediction(file='pilot_1e-1.csv', target='Johannes_choice', lapse=False)
# Out:
# /home/sichao/Documents/Motion/code/sichao/analysis/model.py:38: RuntimeWarning: divide by zero encountered in log
#   loss = -np.log(loss).sum()
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 178.03214683298182
#             Iterations: 24
#             Function evaluations: 152
#             Gradient evaluations: 24
# [3.56778287e-02 8.64316555e+01 4.17920608e+01 2.68260485e+01]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.759356  0.005884  0.154859  0.079902
# GLO           0.005729  0.685692  0.166406  0.142174
# CLU           0.060786  0.028722  0.614678  0.295815
# SDH           0.034819  0.256304  0.408464  0.300413
