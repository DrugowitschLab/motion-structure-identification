# %%
from analysis.confusion_matrix import plot_cm
from analysis.model import plot_prediction

# %%
plot_cm('sichao/pilot_sichao.dat')
# Out:
# [[42  1  6  3]
#  [ 0 33  1  0]
#  [ 3  0 38 11]
#  [ 5  8 26 23]]
# accuracy=0.6800; misclass=0.3200

# %%
plot_prediction('pilot_0.csv', 'Sichao_choice')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 161.35828035315296
#             Iterations: 44
#             Function evaluations: 314
#             Gradient evaluations: 43
# [ 1.99776281e-01  1.50798599e-02  3.26460544e+02 -1.40179259e+02
#  -2.02550299e+02]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.850168  0.049944  0.049944  0.049944
# GLO           0.049944  0.850147  0.049951  0.049958
# CLU           0.077608  0.049944  0.693266  0.179182
# SDH           0.066800  0.049947  0.453110  0.430142

# %%
plot_prediction('pilot_0.04309087(sichao).csv', 'Sichao_choice')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 153.47492971233453
#             Iterations: 33
#             Function evaluations: 241
#             Gradient evaluations: 33
# [ 0.12774077  0.07387043 45.99635594  1.54812918 -9.37439311]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.903718  0.031936  0.032269  0.032077
# GLO           0.032103  0.889955  0.037841  0.040101
# CLU           0.082055  0.032217  0.687562  0.198166
# SDH           0.064554  0.145392  0.424128  0.365925

# %%
plot_prediction('pilot_1.csv', 'Sichao_choice')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 132.57905612135846
#             Iterations: 17
#             Function evaluations: 135
#             Gradient evaluations: 17
# [ 0.03932783  0.40933681  0.4540972  -0.9818154  -3.70573406]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.836445  0.010289  0.118481  0.034785
# GLO           0.011253  0.867493  0.054356  0.066898
# CLU           0.066064  0.036106  0.726858  0.170972
# SDH           0.049854  0.145510  0.410828  0.393809

# %%
plot_cm('johannes/pilot_johannes.dat')
# Out:
# [[36  1  9  6]
#  [ 1 32  0  1]
#  [ 3  0 37 12]
#  [ 5  8 25 24]]
# accuracy=0.6450; misclass=0.3550

# %%
plot_prediction('pilot_0.csv', 'Johannes_choice')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 181.57707645238133
#             Iterations: 39
#             Function evaluations: 282
#             Gradient evaluations: 38
# [ 2.74203676e-01  1.52261888e-02  1.71940030e+02 -5.76507385e+01
#  -1.13444909e+02]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.794347  0.068551  0.068551  0.068551
# GLO           0.068552  0.793701  0.068752  0.068995
# CLU           0.075558  0.068551  0.658432  0.197459
# SDH           0.072634  0.068551  0.422106  0.436709

# %%
plot_prediction('pilot_0.08447111(johannes).csv', 'Johannes_choice')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 172.31200219371334
#             Iterations: 26
#             Function evaluations: 194
#             Gradient evaluations: 26
# [ 0.22574557  0.15198018 20.14179354 -2.01228316 -7.5931047 ]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.830564  0.056436  0.056524  0.056476
# GLO           0.056456  0.826556  0.057695  0.059293
# CLU           0.080058  0.056469  0.680696  0.182777
# SDH           0.070459  0.121058  0.377886  0.430597

# %%
plot_prediction('pilot_1.csv', 'Johannes_choice')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 152.6449243664238
#             Iterations: 20
#             Function evaluations: 156
#             Gradient evaluations: 20
# [ 0.07944417  0.36651739  3.05341841  0.09579613 -2.14664395]
#                    IND       GLO       CLU       SDH
# ground_truth
# IND           0.767033  0.021253  0.149961  0.061752
# GLO           0.020871  0.846568  0.056954  0.075607
# CLU           0.063809  0.048498  0.673111  0.214581
# SDH           0.048936  0.173058  0.368504  0.409502
